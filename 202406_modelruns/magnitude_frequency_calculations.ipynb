# %%
# 16th april

# %%
import functions 


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# i first need to calculate the events - that is dfspot/df column in the sediment file

# can i plot actual dfs against potential? similar to what i did per month but now for

# %%
def magnitude_frequency(sediments_area, column):
    """
    Calculate magnitude-frequency values for a column in a DataFrame.

    Parameters:
    - sediments_area (pandas.DataFrame): Input DataFrame.
    - column (str): Name of the column for which magnitude-frequency values are to be calculated.

    Returns:
    - pandas.DataFrame: DataFrame containing magnitude-frequency values.
    """
    # Copy the DataFrame to avoid modifying the original
    sediments_area = sediments_area.copy()
    
    # Sort data smallest to largest
    sediments_area = sediments_area[sediments_area[column] > 0]
    sediments_sorted = sediments_area.sort_values(by=column)

    # Count total observations
    n = sediments_sorted.shape[0]

    # Add a numbered column 1 -> n to use in return calculation for rank
    sediments_sorted.insert(0, 'rank', range(1, 1 + n))

    # Calculate probability - note you may need to adjust this value based upon the time period of your data
    sediments_sorted["prob"] = ((n - sediments_sorted["rank"] + 1) / (n + 1))

    sediments_sorted["return_period"] = (1 / sediments_sorted["prob"])

    return sediments_sorted

# %%
# test scenario
# langtang, 20, 30, 40 daily

test = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/1landcover_20percent/langtang_climate_cut/12a/Sediment.out')
test2 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/2landcover_20percent/langtang_climate_cut/12a/Sediment.out')

# %%
dfs = magnitude_frequency(test, 'dfs')
dfspot = magnitude_frequency(test, 'dfspot')

dfs2 = magnitude_frequency(test,'dfs')
# dfs

# %%
fontsize = 20

fig, ax = plt.subplots(figsize=(10, 8))

# # transport limited - df
ax.scatter(x = dfs.dfs.values, y=dfs.prob.values,label = 'dfs')
ax.scatter(x = dfspot.dfspot.values, y=dfspot.prob.values,label = 'dfspot')
ax.scatter(x = dfs20.dfspot.values, y=dfs20.prob.values,label = 'dfs20')
plt.legend()

# %%
lc1daily20 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/1landcover_20percent/langtang_climate_cut/12a/Sediment.out')
lc2daily20 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/2landcover_20percent/langtang_climate_cut/12a/Sediment.out')
lc3daily20 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/3landcover_20percent/langtang_climate_cut/12a/Sediment.out')
lc4daily20 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/4landcover_20percent/langtang_climate_cut/12a/Sediment.out')
lc5daily20 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/5landcover_20percent/langtang_climate_cut/12a/Sediment.out')

lc1daily30 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/1landcover_30percent/langtang_climate_cut/12a/Sediment.out')
lc2daily30 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/2landcover_30percent/langtang_climate_cut/12a/Sediment.out')
lc3daily30 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/3landcover_30percent/langtang_climate_cut/12a/Sediment.out')
lc4daily30 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/4landcover_30percent/langtang_climate_cut/12a/Sediment.out')
lc5daily30 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/5landcover_30percent/langtang_climate_cut/12a/Sediment.out')

lc1daily40 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/1landcover_40percent/langtang_climate_cut/12a/Sediment.out')
lc2daily40 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/2landcover_40percent/langtang_climate_cut/12a/Sediment.out')
lc3daily40 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/3landcover_40percent/langtang_climate_cut/12a/Sediment.out')
lc4daily40 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/4landcover_40percent/langtang_climate_cut/12a/Sediment.out')
lc5daily40 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/5landcover_40percent/langtang_climate_cut/12a/Sediment.out')

lc1daily50 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/1landcover_50percent/langtang_climate_cut/12a/Sediment.out')
lc2daily50 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/2landcover_50percent/langtang_climate_cut/12a/Sediment.out')
lc3daily50 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/3landcover_50percent/langtang_climate_cut/12a/Sediment.out')
lc4daily50 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/4landcover_50percent/langtang_climate_cut/12a/Sediment.out')
lc5daily50 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/5landcover_50percent/langtang_climate_cut/12a/Sediment.out')

lc1daily60 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/1landcover_60percent/langtang_climate_cut/12a/Sediment.out')
lc2daily60 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/2landcover_60percent/langtang_climate_cut/12a/Sediment.out')
lc3daily60 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/3landcover_60percent/langtang_climate_cut/12a/Sediment.out')
lc4daily60 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/4landcover_60percent/langtang_climate_cut/12a/Sediment.out')
lc5daily60 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_daily/5landcover_60percent/langtang_climate_cut/12a/Sediment.out')


lc1daily20 = magnitude_frequency(lc1daily20, 'dfs')
lc2daily20 = magnitude_frequency(lc2daily20, 'dfs')
lc3daily20 = magnitude_frequency(lc3daily20, 'dfs')
lc4daily20 = magnitude_frequency(lc4daily20, 'dfs')
lc5daily20 = magnitude_frequency(lc5daily20, 'dfs')

lc1daily30 = magnitude_frequency(lc1daily30, 'dfs')
lc2daily30 = magnitude_frequency(lc2daily30, 'dfs')
lc3daily30 = magnitude_frequency(lc3daily30, 'dfs')
lc4daily30 = magnitude_frequency(lc4daily30, 'dfs')
lc5daily30 = magnitude_frequency(lc5daily30, 'dfs')

lc1daily40 = magnitude_frequency(lc1daily40, 'dfs')
lc2daily40 = magnitude_frequency(lc2daily40, 'dfs')
lc3daily40 = magnitude_frequency(lc3daily40, 'dfs')
lc4daily40 = magnitude_frequency(lc4daily40, 'dfs')
lc5daily40 = magnitude_frequency(lc5daily40, 'dfs')

lc1daily50 = magnitude_frequency(lc1daily50, 'dfs')
lc2daily50 = magnitude_frequency(lc2daily50, 'dfs')
lc3daily50 = magnitude_frequency(lc3daily50, 'dfs')
lc4daily50 = magnitude_frequency(lc4daily50, 'dfs')
lc5daily50 = magnitude_frequency(lc5daily50, 'dfs')

lc1daily60 = magnitude_frequency(lc1daily60, 'dfs')
lc2daily60 = magnitude_frequency(lc2daily60, 'dfs')
lc3daily60 = magnitude_frequency(lc3daily60, 'dfs')
lc4daily60 = magnitude_frequency(lc4daily60, 'dfs')
lc5daily60 = magnitude_frequency(lc5daily60, 'dfs')

# %%
lc1once20 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/1landcover_20percent/langtang_climate_cut/12a/Sediment.out')
lc2once20 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/2landcover_20percent/langtang_climate_cut/12a/Sediment.out')
lc3once20 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/3landcover_20percent/langtang_climate_cut/12a/Sediment.out')
lc4once20 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/4landcover_20percent/langtang_climate_cut/12a/Sediment.out')
lc5once20 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/5landcover_20percent/langtang_climate_cut/12a/Sediment.out')

lc1once30 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/1landcover_30percent/langtang_climate_cut/12a/Sediment.out')
lc2once30 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/2landcover_30percent/langtang_climate_cut/12a/Sediment.out')
lc3once30 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/3landcover_30percent/langtang_climate_cut/12a/Sediment.out')
lc4once30 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/4landcover_30percent/langtang_climate_cut/12a/Sediment.out')
lc5once30 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/5landcover_30percent/langtang_climate_cut/12a/Sediment.out')

lc1once40 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/1landcover_40percent/langtang_climate_cut/12a/Sediment.out')
lc2once40 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/2landcover_40percent/langtang_climate_cut/12a/Sediment.out')
lc3once40 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/3landcover_40percent/langtang_climate_cut/12a/Sediment.out')
lc4once40 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/4landcover_40percent/langtang_climate_cut/12a/Sediment.out')
lc5once40 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/5landcover_40percent/langtang_climate_cut/12a/Sediment.out')

lc1once50 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/1landcover_50percent/langtang_climate_cut/12a/Sediment.out')
lc2once50 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/2landcover_50percent/langtang_climate_cut/12a/Sediment.out')
lc3once50 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/3landcover_50percent/langtang_climate_cut/12a/Sediment.out')
lc4once50 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/4landcover_50percent/langtang_climate_cut/12a/Sediment.out')
lc5once50 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/5landcover_50percent/langtang_climate_cut/12a/Sediment.out')

lc1once60 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/1landcover_60percent/langtang_climate_cut/12a/Sediment.out')
lc2once60 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/2landcover_60percent/langtang_climate_cut/12a/Sediment.out')
lc3once60 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/3landcover_60percent/langtang_climate_cut/12a/Sediment.out')
lc4once60 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/4landcover_60percent/langtang_climate_cut/12a/Sediment.out')
lc5once60 = pd.read_csv('/Volumes/T7 Shield/202409_paper2_modelruns/30years/SL_once/5landcover_60percent/langtang_climate_cut/12a/Sediment.out')


lc1once20 = magnitude_frequency(lc1once20, 'dfs')
lc2once20 = magnitude_frequency(lc2once20, 'dfs')
lc3once20 = magnitude_frequency(lc3once20, 'dfs')
lc4once20 = magnitude_frequency(lc4once20, 'dfs')
lc5once20 = magnitude_frequency(lc5once20, 'dfs')
lc1once30 = magnitude_frequency(lc1once30, 'dfs')
lc2once30 = magnitude_frequency(lc2once30, 'dfs')
lc3once30 = magnitude_frequency(lc3once30, 'dfs')
lc4once30 = magnitude_frequency(lc4once30, 'dfs')
lc5once30 = magnitude_frequency(lc5once30, 'dfs')
lc1once40 = magnitude_frequency(lc1once40, 'dfs')
lc2once40 = magnitude_frequency(lc2once40, 'dfs')
lc3once40 = magnitude_frequency(lc3once40, 'dfs')
lc4once40 = magnitude_frequency(lc4once40, 'dfs')
lc5once40 = magnitude_frequency(lc5once40, 'dfs')
lc1once50 = magnitude_frequency(lc1once50, 'dfs')
lc2once50 = magnitude_frequency(lc2once50, 'dfs')
lc3once50 = magnitude_frequency(lc3once50, 'dfs')
lc4once50 = magnitude_frequency(lc4once50, 'dfs')
lc5once50 = magnitude_frequency(lc5once50, 'dfs')
lc1once60 = magnitude_frequency(lc1once60, 'dfs')
lc2once60 = magnitude_frequency(lc2once60, 'dfs')
lc3once60 = magnitude_frequency(lc3once60, 'dfs')
lc4once60 = magnitude_frequency(lc4once60, 'dfs')
lc5once60 = magnitude_frequency(lc5once60, 'dfs')

# %%
# test plot with 5 land cover panels and once and daily input for diffeent scenarious 


fig = plt.figure(figsize=(20, 8), layout='tight')

mosaic = fig.subplot_mosaic('''
                            abcde
                            ABCDE
                            ''',
                           sharey = True, sharex = True)

mosaic['a'].scatter(x = lc1daily20.dfs.values, y=lc1daily20.prob.values)
mosaic['b'].scatter(x = lc2daily20.dfs.values, y=lc2daily20.prob.values)
mosaic['c'].scatter(x = lc3daily20.dfs.values, y=lc3daily20.prob.values)
mosaic['d'].scatter(x = lc4daily20.dfs.values, y=lc4daily20.prob.values)
mosaic['e'].scatter(x = lc5daily20.dfs.values, y=lc5daily20.prob.values)


mosaic['a'].scatter(x = lc1daily30.dfs.values, y=lc1daily30.prob.values)
mosaic['b'].scatter(x = lc2daily30.dfs.values, y=lc2daily30.prob.values)
mosaic['c'].scatter(x = lc3daily30.dfs.values, y=lc3daily30.prob.values)
mosaic['d'].scatter(x = lc4daily30.dfs.values, y=lc4daily30.prob.values)
mosaic['e'].scatter(x = lc5daily30.dfs.values, y=lc5daily30.prob.values)

mosaic['a'].scatter(x = lc1daily40.dfs.values, y=lc1daily40.prob.values)
mosaic['b'].scatter(x = lc2daily40.dfs.values, y=lc2daily40.prob.values)
mosaic['c'].scatter(x = lc3daily40.dfs.values, y=lc3daily40.prob.values)
mosaic['d'].scatter(x = lc4daily40.dfs.values, y=lc4daily40.prob.values)
mosaic['e'].scatter(x = lc5daily40.dfs.values, y=lc5daily40.prob.values)

mosaic['a'].scatter(x = lc1daily50.dfs.values, y=lc1daily50.prob.values)
mosaic['b'].scatter(x = lc2daily50.dfs.values, y=lc2daily50.prob.values)
mosaic['c'].scatter(x = lc3daily50.dfs.values, y=lc3daily50.prob.values)
mosaic['d'].scatter(x = lc4daily50.dfs.values, y=lc4daily50.prob.values)
mosaic['e'].scatter(x = lc5daily50.dfs.values, y=lc5daily50.prob.values)

mosaic['a'].scatter(x = lc1daily60.dfs.values, y=lc1daily60.prob.values)
mosaic['b'].scatter(x = lc2daily60.dfs.values, y=lc2daily60.prob.values)
mosaic['c'].scatter(x = lc3daily60.dfs.values, y=lc3daily60.prob.values)
mosaic['d'].scatter(x = lc4daily60.dfs.values, y=lc4daily60.prob.values)
mosaic['e'].scatter(x = lc5daily60.dfs.values, y=lc5daily60.prob.values)






mosaic['A'].scatter(x = lc1once20.dfs.values, y=lc1once20.prob.values, label = '20 percent')
mosaic['B'].scatter(x = lc2once20.dfs.values, y=lc2once20.prob.values)
mosaic['C'].scatter(x = lc3once20.dfs.values, y=lc3once20.prob.values)
mosaic['D'].scatter(x = lc4once20.dfs.values, y=lc4once20.prob.values)
mosaic['E'].scatter(x = lc5once20.dfs.values, y=lc5once20.prob.values)

mosaic['A'].scatter(x = lc1once30.dfs.values, y=lc1once30.prob.values, label = '30 percent')
mosaic['B'].scatter(x = lc2once30.dfs.values, y=lc2once30.prob.values)
mosaic['C'].scatter(x = lc3once30.dfs.values, y=lc3once30.prob.values)
mosaic['D'].scatter(x = lc4once30.dfs.values, y=lc4once30.prob.values)
mosaic['E'].scatter(x = lc5once30.dfs.values, y=lc5once30.prob.values)

mosaic['A'].scatter(x = lc1once40.dfs.values, y=lc1once40.prob.values, label = '40 percent')
mosaic['B'].scatter(x = lc2once40.dfs.values, y=lc2once40.prob.values)
mosaic['C'].scatter(x = lc3once40.dfs.values, y=lc3once40.prob.values)
mosaic['D'].scatter(x = lc4once40.dfs.values, y=lc4once40.prob.values)
mosaic['E'].scatter(x = lc5once40.dfs.values, y=lc5once40.prob.values)

mosaic['A'].scatter(x = lc1once50.dfs.values, y=lc1once50.prob.values, label = '50 percent')
mosaic['B'].scatter(x = lc2once50.dfs.values, y=lc2once50.prob.values)
mosaic['C'].scatter(x = lc3once50.dfs.values, y=lc3once50.prob.values)
mosaic['D'].scatter(x = lc4once50.dfs.values, y=lc4once50.prob.values)
mosaic['E'].scatter(x = lc5once50.dfs.values, y=lc5once50.prob.values)

mosaic['A'].scatter(x = lc1once60.dfs.values, y=lc1once60.prob.values, label = '60 percent')
mosaic['B'].scatter(x = lc2once60.dfs.values, y=lc2once60.prob.values)
mosaic['C'].scatter(x = lc3once60.dfs.values, y=lc3once60.prob.values)
mosaic['D'].scatter(x = lc4once60.dfs.values, y=lc4once60.prob.values)
mosaic['E'].scatter(x = lc5once60.dfs.values, y=lc5once60.prob.values)



for key in ['A', 'B', 'C', 'D', 'E']:
    mosaic[key].set_xscale('log')
    # mosaic[key].set_yscale('log')

mosaic['A'].legend()
mosaic['A'].set_xlabel('dfs - volume')
mosaic['A'].set_ylabel('probability')
# Out:
# Text(0, 0.5, 'probability')

# %%
plt.scatter(x = lc1daily60.dfspot, y = lc1daily60.dfs)
plt.scatter(x = lc1daily60.dfspot, y = lc1daily60.dfs)
plt.scatter(x = lc1daily60.dfspot, y = lc1daily60.dfs)
plt.scatter(x = lc1daily60.dfspot, y = lc1daily60.dfs)

# %%
fig = plt.figure(figsize=(20, 8), layout='tight')

mosaic = fig.subplot_mosaic('''
                            abcde
                            ABCDE
                            ''',
                           sharey = True, sharex = True)


mosaic['a'].scatter(x = lc1daily20.dfspot, y = lc1daily20.dfs, label = '20 percent - daily')
mosaic['a'].scatter(x = lc1daily30.dfspot, y = lc1daily30.dfs, label = '30 percent - daily')
mosaic['a'].scatter(x = lc1daily40.dfspot, y = lc1daily40.dfs, label = '40 percent - daily')
mosaic['a'].scatter(x = lc1daily50.dfspot, y = lc1daily50.dfs, label = '50 percent - daily')
mosaic['a'].scatter(x = lc1daily50.dfspot, y = lc1daily50.dfs, label = '60 percent - daily')
mosaic['a'].legend()

mosaic['b'].scatter(x = lc2daily20.dfspot, y = lc2daily20.dfs)
mosaic['b'].scatter(x = lc2daily30.dfspot, y = lc2daily30.dfs)
mosaic['b'].scatter(x = lc2daily40.dfspot, y = lc2daily40.dfs)
mosaic['b'].scatter(x = lc2daily50.dfspot, y = lc2daily50.dfs)
mosaic['b'].scatter(x = lc2daily60.dfspot, y = lc2daily60.dfs)

mosaic['c'].scatter(x = lc3daily20.dfspot, y = lc3daily20.dfs)
mosaic['c'].scatter(x = lc3daily30.dfspot, y = lc3daily30.dfs)
mosaic['c'].scatter(x = lc3daily40.dfspot, y = lc3daily40.dfs)
mosaic['c'].scatter(x = lc3daily50.dfspot, y = lc3daily50.dfs)
mosaic['c'].scatter(x = lc3daily60.dfspot, y = lc3daily60.dfs)

mosaic['d'].scatter(x = lc4daily20.dfspot, y = lc4daily20.dfs)
mosaic['d'].scatter(x = lc4daily30.dfspot, y = lc4daily30.dfs)
mosaic['d'].scatter(x = lc4daily40.dfspot, y = lc4daily40.dfs)
mosaic['d'].scatter(x = lc4daily50.dfspot, y = lc4daily50.dfs)
mosaic['d'].scatter(x = lc4daily60.dfspot, y = lc4daily60.dfs)

mosaic['e'].scatter(x = lc5daily20.dfspot, y = lc5daily20.dfs)
mosaic['e'].scatter(x = lc5daily30.dfspot, y = lc5daily30.dfs)
mosaic['e'].scatter(x = lc5daily40.dfspot, y = lc5daily40.dfs)
mosaic['e'].scatter(x = lc5daily50.dfspot, y = lc5daily50.dfs)
mosaic['e'].scatter(x = lc5daily60.dfspot, y = lc5daily60.dfs)



# ----- once
mosaic['A'].scatter(x = lc1once20.dfspot, y = lc1once20.dfs, label = '20 percent - once')
mosaic['A'].scatter(x = lc1once30.dfspot, y = lc1once30.dfs, label = '30 percent - once')
mosaic['A'].scatter(x = lc1once40.dfspot, y = lc1once40.dfs, label = '40 percent - once')
mosaic['A'].scatter(x = lc1once50.dfspot, y = lc1once50.dfs, label = '50 percent - once')
mosaic['A'].scatter(x = lc1once50.dfspot, y = lc1once50.dfs, label = '60 percent - once')
mosaic['A'].legend()

mosaic['B'].scatter(x = lc2once20.dfspot, y = lc2once20.dfs)
mosaic['B'].scatter(x = lc2once30.dfspot, y = lc2once30.dfs)
mosaic['B'].scatter(x = lc2once40.dfspot, y = lc2once40.dfs)
mosaic['B'].scatter(x = lc2once50.dfspot, y = lc2once50.dfs)
mosaic['B'].scatter(x = lc2once60.dfspot, y = lc2once60.dfs)

mosaic['C'].scatter(x = lc3once20.dfspot, y = lc3once20.dfs)
mosaic['C'].scatter(x = lc3once30.dfspot, y = lc3once30.dfs)
mosaic['C'].scatter(x = lc3once40.dfspot, y = lc3once40.dfs)
mosaic['C'].scatter(x = lc3once50.dfspot, y = lc3once50.dfs)
mosaic['C'].scatter(x = lc3once60.dfspot, y = lc3once60.dfs)

mosaic['D'].scatter(x = lc4once20.dfspot, y = lc4once20.dfs)
mosaic['D'].scatter(x = lc4once30.dfspot, y = lc4once30.dfs)
mosaic['D'].scatter(x = lc4once40.dfspot, y = lc4once40.dfs)
mosaic['D'].scatter(x = lc4once50.dfspot, y = lc4once50.dfs)
mosaic['D'].scatter(x = lc4once60.dfspot, y = lc4once60.dfs)

mosaic['E'].scatter(x = lc5once20.dfspot, y = lc5once20.dfs)
mosaic['E'].scatter(x = lc5once30.dfspot, y = lc5once30.dfs)
mosaic['E'].scatter(x = lc5once40.dfspot, y = lc5once40.dfs)
mosaic['E'].scatter(x = lc5once50.dfspot, y = lc5once50.dfs)
mosaic['E'].scatter(x = lc5once60.dfspot, y = lc5once60.dfs)


mosaic['A'].set_xlabel('dfspot')
mosaic['A'].set_ylabel('dfs')
# Out:
# Text(0, 0.5, 'dfs')

# %%
fig = plt.figure(figsize=(20, 8), layout='tight')

mosaic = fig.subplot_mosaic('''
                            a
                            b
                            ''',
                           sharey = True, sharex = True)


# # sns.histplot(lc1once20.dfspot, ax = mosaic['a'])
# sns.histplot(lc1daily20.dfs, ax = mosaic['a'])
# sns.histplot(lc1daily30.dfs, ax = mosaic['a'])
# sns.histplot(lc1daily40.dfs, ax = mosaic['a'])
# sns.histplot(lc1daily50.dfs, ax = mosaic['a'])
# sns.histplot(lc1daily60.dfs, ax = mosaic['a'])

# sns.histplot(lc1once20.dfs, ax = mosaic['b'])
# sns.histplot(lc1once30.dfs, ax = mosaic['b'])
# sns.histplot(lc1once40.dfs, ax = mosaic['b'])
# sns.histplot(lc1once50.dfs, ax = mosaic['b'])
# sns.histplot(lc1once60.dfs, ax = mosaic['b'])


sns.histplot(lc1daily60.dfs, ax = mosaic['a'])
sns.histplot(lc1once60.dfs, ax = mosaic['a'])

sns.histplot(lc1daily20.dfs, ax = mosaic['b'])
sns.histplot(lc1once20.dfs, ax = mosaic['b'])
# Out:
# <AxesSubplot:label='b', xlabel='dfs', ylabel='Count'>

# %%
fig = plt.figure(figsize=(10, 8), layout='tight')

mosaic = fig.subplot_mosaic('''
                            ab
                            cd
                            ''',
                           sharey = True, sharex = True)


sns.histplot(lc1once20, x ='dfspot', y ='dfs', ax = mosaic['a'], color = 'blue')
sns.histplot(lc1once60, x ='dfspot', y ='dfs', ax = mosaic['a'], color = 'red')

sns.histplot(lc2once20, x ='dfspot', y ='dfs', ax = mosaic['b'])
sns.histplot(lc3once20, x ='dfspot', y ='dfs', ax = mosaic['c'])
sns.histplot(lc4once20, x ='dfspot', y ='dfs', ax = mosaic['d'])
# Out:
# <AxesSubplot:label='d', xlabel='dfspot', ylabel='dfs'>

# %%
sns.jointplot(data=lc1once20, x="dfspot", y="dfs")
