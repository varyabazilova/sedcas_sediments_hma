# %%
import pandas as pd
import os

# %%
def update_parameter_file(folder, paramfile, value):
    # Iterate over all folders in the given directory
    for folder_name in os.listdir(folder):
        folder_path = os.path.join(folder, folder_name)

        # Check if it's a directory
        if os.path.isdir(folder_path):
            paramfile_path = os.path.join(folder_path, paramfile)

            # Check if the parameter file exists in the folder
            if os.path.exists(paramfile_path):
                with open(paramfile_path, 'r') as file:
                    lines = file.readlines()

                # Update the specific line with the new value
                for i, line in enumerate(lines):
                    if line.startswith("shares:"):
                        lines[i] = f"shares:{value}\n"
                        break

                # Write the updated lines back to the parameter file
                with open(paramfile_path, 'w') as file:
                    file.writelines(lines)
                print(f"Updated {paramfile_path}")
            else:
                print(f"{paramfile} not found in {folder_name}")


# folder = '/Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/3landcover/mustang_climate_cut/'
folder = '/Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/'


paramfile = 'parameters.par'

# shares - values of the fraction of the land cover 
# forest, bedrock, glacier

value_landcover1 = [0.4, 0.4, 0.2]
value_landcover2 = [0.4, 0.5, 0.1]  
value_landcover3 = [0.5, 0.4, 0.1] 
value_landcover4 = [0.4, 0.6, 0.0] # reference


# new landcover with big forest and no glacier
value_landcover5 = [0.6, 0.4, 0.0] # reference



update_parameter_file(folder, paramfile, value_landcover5)
# Out:
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/19b/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/13b/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/19c/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/19d/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/13d/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/30a/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/13c/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/21a/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/28a/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/22a/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/23b/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/20c/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/20d/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/29b/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/20b/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/23d/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/23c/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/29c/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/29d/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/31b/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/38d/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/14b/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/38c/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/31d/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/12a/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/31c/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/38b/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/14d/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/14c/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/30d/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/30c/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/13a/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/19a/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/30b/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/21b/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/22d/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/22c/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/28c/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/28d/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/22b/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/21c/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/21d/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/28b/parameters.par
# parameters.par not found in .ipynb_checkpoints
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/29a/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/23a/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/20a/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/14a/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/12d/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/12c/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/31a/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/38a/parameters.par
# Updated /Users/varyabazilova/Desktop/paper2/202406_modelruns/30years/TL_data/5landcover/langtang_climate_cut/12b/parameters.par
