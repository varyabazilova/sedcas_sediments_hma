# %%
import os
import pandas as pd
import matplotlib.pyplot as plt


# modelling part
from run import run

# %%
# %%time

climatepath = '/Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test'




# get all folders togetehr 
# ls_ = os.listdir('./langtang')
ls_ = os.listdir(climatepath)
ls = [d for d in ls_ if not d.startswith('.')]
dir0 = os.getcwd()

# run the model for each
for d in ls:
    path = os.path.join(dir0, '1langtangSL/default_land_cover/100percent_test', d)
    print(path)
    os.chdir(path)
    run()
    os.chdir(dir0)
# Out:
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr20a
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.54s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr29a
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.34s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr23a
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.34s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr38a
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.32s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr12b
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.49s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr14a
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.50s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr12d
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.38s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr12c
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.48s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr31a
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.45s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr30b
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.45s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr30d
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.39s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr30c
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.41s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr13a
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.68s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr19a
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.82s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr21c
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.63s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr21d
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.43s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr22b
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.43s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr28b
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.33s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr22d
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.42s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr22c
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.48s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr21b
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.44s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/SedCas_glacier_sed.py:221: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr28c
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.65s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr28d
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.45s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr23d
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.37s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr23c
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.63s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr20b
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.39s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr29c
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.68s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr29d
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.63s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr20c
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.48s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr20d
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.88s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr23b
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.94s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr29b
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.03s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr31d
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.16s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr12a
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.86s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr31c
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.59s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr14d
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.53s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr38b
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.88s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr14c
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.66s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr31b
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.41s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr14b
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.52s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr38d
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.32s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr38c
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.36s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr19c
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.82s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr19d
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.44s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr13d
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.37s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr30a
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.46s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr13c
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.45s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr19b
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.51s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr13b
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.53s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr28a
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.33s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr22a
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.35s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/202405_modelruns/1langtangSL/default_land_cover/100percent_test/cellnr21a
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.38s/it]
# saving output...
# CPU times: user 24min 57s, sys: 16.1 s, total: 25min 13s
# Wall time: 25min 40s
