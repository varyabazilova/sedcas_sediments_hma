# %% [markdown]
# - iterate over the cells
# - save hydrology and sediments
# - make sure to save the ls, sc
#
# 1. Experiment 1: NO GLACIERS
# 2. Experiment 2: transport limited case (!!! HERE: calculate what is the mean annual sedimant yeild)
# 3. Experiment 3: linear increase in sediment storage: (i) mean annual, (ii) 25 percent, (iii) 50 percent, (iv) 75 percent

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt


# modelling part
from run import run

# %% [markdown]
# ### sediment supply limited: mean annual sediment yeild / 365 (m3/day)

# %%
# %%time
climatepath = '/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annual_mean'

# get all folders togetehr 
# ls_ = os.listdir('./langtang')
ls_ = os.listdir(climatepath)
ls = [d for d in ls_ if not d.startswith('.')]
dir0 = os.getcwd()

# run the model for each
for d in ls:
    path = os.path.join(dir0, 'langtang_annual_mean', d)
    print(path)
    os.chdir(path)
    run()
    os.chdir(dir0)
# Out:
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annual_mean/cellnr29
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.55s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annual_mean/cellnr20
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.57s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annual_mean/cellnr19
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.68s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annual_mean/cellnr21
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.57s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annual_mean/cellnr28
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.59s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annual_mean/cellnr12
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.59s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annual_mean/cellnr23
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.09s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annual_mean/cellnr22
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.11s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annual_mean/cellnr13
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.62s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annual_mean/cellnr14
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.60s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annual_mean/cellnr31
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.05s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annual_mean/cellnr38
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.15s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annual_mean/cellnr30
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.09s/it]
# saving output...
# CPU times: user 6min 11s, sys: 2.24 s, total: 6min 14s
# Wall time: 6min 15s

# %% [markdown]
# ### sediment supply limited: 25 percentile of mean annual sediment yeild / 365 (m3/day)

# %%
# %%time
climatepath = '/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean25percent'

# get all folders togetehr 
# ls_ = os.listdir('./langtang')
ls_ = os.listdir(climatepath)
ls = [d for d in ls_ if not d.startswith('.')]
dir0 = os.getcwd()

# run the model for each
for d in ls:
    path = os.path.join(dir0, 'langtang_annuall_mean25percent', d)
    print(path)
    os.chdir(path)
    run()
    os.chdir(dir0)
# Out:
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean25percent/cellnr29
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.51s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean25percent/cellnr20
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.63s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean25percent/cellnr19
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.71s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean25percent/cellnr21
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.57s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean25percent/cellnr28
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.59s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean25percent/cellnr12
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.58s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean25percent/cellnr23
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.13s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean25percent/cellnr22
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.12s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean25percent/cellnr13
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.61s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean25percent/cellnr14
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.60s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean25percent/cellnr31
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.10s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean25percent/cellnr38
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.14s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean25percent/cellnr30
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.07s/it]
# saving output...
# CPU times: user 6min 13s, sys: 1.86 s, total: 6min 15s
# Wall time: 6min 17s

# %% [markdown]
# ### sediment supply limited: 50 percentile of mean annual sediment yeild / 365 (m3/day)

# %%
# %%time


climatepath = '/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean50percent'

# get all folders togetehr 
# ls_ = os.listdir('./langtang')
ls_ = os.listdir(climatepath)
ls = [d for d in ls_ if not d.startswith('.')]
dir0 = os.getcwd()

# run the model for each
for d in ls:
    path = os.path.join(dir0, 'langtang_annuall_mean50percent', d)
    print(path)
    os.chdir(path)
    run()
    os.chdir(dir0)
# Out:
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean50percent/cellnr29
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.44s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean50percent/cellnr20
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.61s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean50percent/cellnr19
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.68s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean50percent/cellnr21
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.57s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean50percent/cellnr28
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.65s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean50percent/cellnr12
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.58s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean50percent/cellnr23
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.13s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean50percent/cellnr22
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.09s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean50percent/cellnr13
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.61s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean50percent/cellnr14
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.60s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean50percent/cellnr31
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.11s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean50percent/cellnr38
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.07s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean50percent/cellnr30
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.12s/it]
# saving output...
# CPU times: user 6min 13s, sys: 1.79 s, total: 6min 15s
# Wall time: 6min 16s

# %% [markdown]
# ### sediment supply limited: 75 percentile of mean annual sediment yeild / 365 (m3/day)

# %%
# %%time

climatepath = '/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean75percent'

# get all folders togetehr 
# ls_ = os.listdir('./langtang')
ls_ = os.listdir(climatepath)
ls = [d for d in ls_ if not d.startswith('.')]
dir0 = os.getcwd()

# run the model for each
for d in ls:
    path = os.path.join(dir0, 'langtang_annuall_mean75percent', d)
    print(path)
    os.chdir(path)
    run()
    os.chdir(dir0)
# Out:
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean75percent/cellnr29
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.44s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean75percent/cellnr20
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.56s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean75percent/cellnr19
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.68s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean75percent/cellnr21
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.61s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean75percent/cellnr28
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.59s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean75percent/cellnr12
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.57s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean75percent/cellnr23
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.05s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean75percent/cellnr22
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.15s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean75percent/cellnr13
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.61s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean75percent/cellnr14
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.60s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean75percent/cellnr31
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.10s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean75percent/cellnr38
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.11s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_annuall_mean75percent/cellnr30
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.07s/it]
# saving output...
# CPU times: user 6min 13s, sys: 1.63 s, total: 6min 14s
# Wall time: 6min 15s

# %% [markdown]
# ### sediment supply limited: 100 m3/day

# %%
# %%time
# climatepath = '/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang100m3'

# # get all folders togetehr 
# # ls_ = os.listdir('./langtang')
# ls_ = os.listdir(climatepath)
# ls = [d for d in ls_ if not d.startswith('.')]
# dir0 = os.getcwd()

# # run the model for each
# for d in ls:
#     path = os.path.join(dir0, 'langtang100m3', d)
#     print(path)
#     os.chdir(path)
#     run()
#     os.chdir(dir0)

# %% [markdown]
# # GLACIERS (i) mean annual sediment yeld as input

# %%
# %%time
climatepath = '/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_annual_mean'
output_folder = 'langtang_GL_annual_mean'

# get all folders togetehr 
# ls_ = os.listdir('./langtang')
ls_ = os.listdir(climatepath)
ls = [d for d in ls_ if not d.startswith('.')]
dir0 = os.getcwd()

# run the model for each
for d in ls:
    path = os.path.join(dir0, output_folder, d)
    print(path)
    os.chdir(path)
    run()
    os.chdir(dir0)
# Out:
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_annual_mean/cellnr29
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.66s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_annual_mean/cellnr20
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.56s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_annual_mean/cellnr19
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.67s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_annual_mean/cellnr21
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.57s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_annual_mean/cellnr28
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.59s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_annual_mean/cellnr12
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.58s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_annual_mean/cellnr23
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.18s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_annual_mean/cellnr22
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.64s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_annual_mean/cellnr13
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.62s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_annual_mean/cellnr14
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.65s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_annual_mean/cellnr31
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.15s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_annual_mean/cellnr38
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.06s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_annual_mean/cellnr30
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.94s/it]
# saving output...
# CPU times: user 6min 2s, sys: 1.86 s, total: 6min 4s
# Wall time: 6min 4s

# %% [markdown]
# # GLACIERS (ii) 25% of mean annual sediment yeld as input

# %%
# %%time
climatepath = '/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean25percent'
output_folder = 'langtang_GL_mean25percent'

# get all folders togetehr 
# ls_ = os.listdir('./langtang')
ls_ = os.listdir(climatepath)
ls = [d for d in ls_ if not d.startswith('.')]
dir0 = os.getcwd()

# run the model for each
for d in ls:
    path = os.path.join(dir0, output_folder, d)
    print(path)
    os.chdir(path)
    run()
    os.chdir(dir0)
# Out:
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean25percent/cellnr29
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.02s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean25percent/cellnr20
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.56s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean25percent/cellnr19
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.75s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean25percent/cellnr21
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.62s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean25percent/cellnr28
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.64s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean25percent/cellnr12
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.57s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean25percent/cellnr23
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.12s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean25percent/cellnr22
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.08s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean25percent/cellnr13
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.61s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean25percent/cellnr14
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.62s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean25percent/cellnr31
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.29s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean25percent/cellnr38
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.16s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean25percent/cellnr30
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.13s/it]
# saving output...
# CPU times: user 6min 19s, sys: 1.91 s, total: 6min 21s
# Wall time: 6min 23s

# %% [markdown]
# # GLACIERS (iii) 50% of mean annual sediment yeld as input

# %%
# %%time
climatepath = '/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean50percent'
output_folder = 'langtang_GL_mean50percent'

# get all folders togetehr 
# ls_ = os.listdir('./langtang')
ls_ = os.listdir(climatepath)
ls = [d for d in ls_ if not d.startswith('.')]
dir0 = os.getcwd()

# run the model for each
for d in ls:
    path = os.path.join(dir0, output_folder, d)
    print(path)
    os.chdir(path)
    run()
    os.chdir(dir0)
# Out:
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean50percent/cellnr29
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.16s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean50percent/cellnr20
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.57s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean50percent/cellnr19
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.77s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean50percent/cellnr21
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.64s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean50percent/cellnr28
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.65s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean50percent/cellnr12
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.62s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean50percent/cellnr23
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.53s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean50percent/cellnr22
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.43s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean50percent/cellnr13
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.65s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean50percent/cellnr14
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.67s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean50percent/cellnr31
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.38s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean50percent/cellnr38
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.21s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean50percent/cellnr30
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.64s/it]
# saving output...
# CPU times: user 6min 23s, sys: 2.4 s, total: 6min 26s
# Wall time: 6min 28s

# %% [markdown]
# # GLACIERS (iv) 75% of mean annual sediment yeld as input

# %%
# %%time
climatepath = '/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean75percent'
output_folder = 'langtang_GL_mean75percent'

# get all folders togetehr 
# ls_ = os.listdir('./langtang')
ls_ = os.listdir(climatepath)
ls = [d for d in ls_ if not d.startswith('.')]
dir0 = os.getcwd()

# run the model for each
for d in ls:
    path = os.path.join(dir0, output_folder, d)
    print(path)
    os.chdir(path)
    run()
    os.chdir(dir0)
# Out:
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean75percent/cellnr29
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.19s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean75percent/cellnr20
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.98s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean75percent/cellnr19
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.73s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean75percent/cellnr21
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.58s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean75percent/cellnr28
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.66s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean75percent/cellnr12
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.65s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean75percent/cellnr23
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.24s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean75percent/cellnr22
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.24s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean75percent/cellnr13
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.63s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean75percent/cellnr14
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.61s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean75percent/cellnr31
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.19s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean75percent/cellnr38
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.47s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang_GL_mean75percent/cellnr30
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.30s/it]
# saving output...
# CPU times: user 6min 24s, sys: 2.91 s, total: 6min 27s
# Wall time: 6min 31s

# %% [markdown]
# # test saving dfs column

# %%
# %%time
climatepath = '/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang100m3'
output_folder = 'langtang100m3'

# get all folders togetehr 
# ls_ = os.listdir('./langtang')
ls_ = os.listdir(climatepath)
ls = [d for d in ls_ if not d.startswith('.')]
dir0 = os.getcwd()

# run the model for each
for d in ls:
    path = os.path.join(dir0, output_folder, d)
    print(path)
    os.chdir(path)
    run()
    os.chdir(dir0)
# Out:
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang100m3/cellnr29
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.52s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang100m3/cellnr20
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.58s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang100m3/cellnr19
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.68s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang100m3/cellnr21
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.57s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang100m3/cellnr28
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.61s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang100m3/cellnr12
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.78s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang100m3/cellnr23
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.92s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang100m3/cellnr22
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.52s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang100m3/cellnr13
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.83s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang100m3/cellnr14
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.72s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang100m3/cellnr31
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.63s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang100m3/cellnr38
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.56s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited/langtang100m3/cellnr30
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.56s/it]
# saving output...
# CPU times: user 5min 47s, sys: 3.43 s, total: 5min 51s
# Wall time: 5min 56s
