# %% [markdown]
# - iterate over the cells
# - save hydrology and sediments
# - make sure to save the ls, sc
#
# 1. Experiment 1: NO GLACIERS
# 2. Experiment 2: transport limited case (!!! HERE: calculate what is the mean annual sedimant yeild)
# 3. Experiment 3: linear increase in sediment storage: (i) mean annual, (ii) 25 percent, (iii) 50 percent, (iv) 75 percent

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt


# modelling part
from run import run

# %% [markdown]
# ### sediment supply limited: mean annual sediment yeild / 365 (m3/day)

# %%
climatepath = '/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/langtang_annual_mean'

# get all folders togetehr 
# ls_ = os.listdir('./langtang')
ls_ = os.listdir(climatepath)
ls = [d for d in ls_ if not d.startswith('.')]
dir0 = os.getcwd()

# run the model for each
for d in ls:
    path = os.path.join(dir0, 'langtang', d)
    print(path)
    os.chdir(path)
    run()
    os.chdir(dir0)

# %% [markdown]
# ### sediment supply limited: 25 percentile of mean annual sediment yeild / 365 (m3/day)

# %%
climatepath = '/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/langtang_annuall_mean25percent'

# get all folders togetehr 
# ls_ = os.listdir('./langtang')
ls_ = os.listdir(climatepath)
ls = [d for d in ls_ if not d.startswith('.')]
dir0 = os.getcwd()

# run the model for each
for d in ls:
    path = os.path.join(dir0, 'langtang_annuall_mean25percent', d)
    print(path)
    os.chdir(path)
    run()
    os.chdir(dir0)

# %% [markdown]
# ### sediment supply limited: 50 percentile of mean annual sediment yeild / 365 (m3/day)

# %%
climatepath = '/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/langtang_annuall_mean50percent'

# get all folders togetehr 
# ls_ = os.listdir('./langtang')
ls_ = os.listdir(climatepath)
ls = [d for d in ls_ if not d.startswith('.')]
dir0 = os.getcwd()

# run the model for each
for d in ls:
    path = os.path.join(dir0, 'langtang_annuall_mean50percent', d)
    print(path)
    os.chdir(path)
    run()
    os.chdir(dir0)

# %% [markdown]
# ### sediment supply limited: 75 percentile of mean annual sediment yeild / 365 (m3/day)

# %%
# %%time

climatepath = '/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/langtang_annuall_mean75percent'

# get all folders togetehr 
# ls_ = os.listdir('./langtang')
ls_ = os.listdir(climatepath)
ls = [d for d in ls_ if not d.startswith('.')]
dir0 = os.getcwd()

# run the model for each
for d in ls:
    path = os.path.join(dir0, 'langtang_annuall_mean75percent', d)
    print(path)
    os.chdir(path)
    run()
    os.chdir(dir0)
# Out:
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/langtang_annuall_mean75percent/cellnr29
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.56s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/langtang_annuall_mean75percent/cellnr20
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:03<00:00,  3.44s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/langtang_annuall_mean75percent/cellnr19
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.65s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/langtang_annuall_mean75percent/cellnr21
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:03<00:00,  3.70s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/langtang_annuall_mean75percent/cellnr28
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:03<00:00,  3.80s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/langtang_annuall_mean75percent/cellnr12
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.42s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/langtang_annuall_mean75percent/cellnr23
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.05s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/langtang_annuall_mean75percent/cellnr22
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.04s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/langtang_annuall_mean75percent/cellnr13
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.37s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/langtang_annuall_mean75percent/cellnr14
# running sediment module...
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.45s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/langtang_annuall_mean75percent/cellnr31
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.09s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/langtang_annuall_mean75percent/cellnr38
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.03s/it]
# saving output...
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/langtang_annuall_mean75percent/cellnr30
# running sediment module...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]/Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/modules.py:829: RuntimeWarning: divide by zero encountered in true_divide
#   lrg_ls = mags / area * 10. ** -3  # convert m3 to mm
# /Users/varyabazilova/Desktop/paper2/downscaling_simple/supply_limited_annual_mean/modules.py:1079: RuntimeWarning: invalid value encountered in double_scalars
#   sc[i] = sc[i-1] + ls[i] - redep          # channel storage change
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.08s/it]
# saving output...
# CPU times: user 6min 19s, sys: 2.03 s, total: 6min 21s
# Wall time: 6min 22s
